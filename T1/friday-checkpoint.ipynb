# %%
import matplotlib.pyplot as plt
import networkx as nx

data={ "p1":[0,1,1,0,1],"p2":[0,0,1,0,1], "p3":[1,1,0,1,1], "p4":[1,1,1,0,0],"p5":[1,1,0,0,0]}


g=nx.DiGraph()
g.add_nodes_from(data.keys())

for i,j in enumerate(data):
    for k,h in enumerate(data[j]):
        if h==1:
            g.add_edge(j,list(data.keys())[k])

nx.draw(g,with_labels=True , node_size=1000 ,node_color="red",width=5)
plt.show()

# %%
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt

f=open("1.txt")
x=f.read()
st=set(STOPWORDS)

y = WordCloud(background_color="black",stopwords=st,max_words=20)
y.generate(x)
plt.imshow(y)
plt.axis("off")
plt.show()

# %%
import folium
map=folium.Map(location=[23.040796232074094, 72.50026849791053],zoom_starts=15000)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# %%
m1=folium.Map()
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m1=folium.Map([23.01892617241279, 72.56466426147792])
folium.Marker([23.01892617241279, 72.56466426147792],zoom_start=15,tooltip="AHMEDABAD",popup="Amazing Ahmedabad",
             icon=folium.features.Icon(icon="airoplane")).add_to(m1)
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m2=folium.Map([22.070879902740213, 69.41354448231402])
folium.CircleMarker([22.070879902740213, 69.41354448231402],zoom_start=5,radius=100,color="red",
            tooltip="Paresh home",popup="big farm",fill=True,fill_color="pink",fill_opacity=0.6).add_to(m2)
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd
f=pd.read_csv("Police_Department_Incidents_-_Previous_Year__2016_.csv")
x=pd.DataFrame(f)
x
# Out:
#         IncidntNum        Category  \
# 0        120058272     WEAPON LAWS
# 1        120058272     WEAPON LAWS
# 2        141059263        WARRANTS
# 3        160013662    NON-CRIMINAL
# 4        160002740    NON-CRIMINAL
# ...            ...             ...
# 150495   161061000         ASSAULT
# 150496   176000742    NON-CRIMINAL
# 150497   176000758   LARCENY/THEFT
# 150498   176000764   LARCENY/THEFT
# 150499   179002868  OTHER OFFENSES
#
#                                                  Descript DayOfWeek  \
# 0                               POSS OF PROHIBITED WEAPON    Friday
# 1          FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday
# 2                                          WARRANT ARREST    Monday
# 3                                           LOST PROPERTY   Tuesday
# 4                                           LOST PROPERTY    Friday
# ...                                                   ...       ...
# ...

# %%
x=x.iloc[1:100]
x
# Out:
#     IncidntNum        Category  \
# 1    120058272     WEAPON LAWS
# 2    141059263        WARRANTS
# 3    160013662    NON-CRIMINAL
# 4    160002740    NON-CRIMINAL
# 5    160002869         ASSAULT
# ..         ...             ...
# 95   160014858  OTHER OFFENSES
# 96   160015163    NON-CRIMINAL
# 97   160015276        BURGLARY
# 98   160015276   LARCENY/THEFT
# 99   160015282   LARCENY/THEFT
#
#                                              Descript  DayOfWeek  \
# 1      FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE     Friday
# 2                                      WARRANT ARREST     Monday
# 3                                       LOST PROPERTY    Tuesday
# 4                                       LOST PROPERTY     Friday
# 5                                             BATTERY     Friday
# ..                                                ...        ...
# 95  FRAUDULENT GAME OR TRICK, OBTAINING MONEY OR P...  Wednesday
# ...

# %%
map1=folium.Map(location=[37.77,-122.44],zoom_start=8)
# k=folium.map.FeatureGroup()
for i,j,cat,des in zip(x.Y,x.X,x.Category,x.Descript):
    folium.Marker([i,j],zoom_start=5,tooltip=cat,popup=des).add_to(map1)
map1.add_child(k)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
a1=folium.Map([23.042176512755024, 72.49544936506344])
folium.Marker([23.042176512755024, 72.49544936506344],zoom_start=15,tooltip="sindhubhavan",popup="Amazing Ahmedabad",
             icon=folium.features.Icon(icon="airoplane")).add_to(a1)
folium.Marker([23.049818869897805, 72.66917726698695],zoom_start=15,tooltip="nikol",popup="Amazing Ahmedabad",
             icon=folium.features.Icon(icon="airoplane")).add_to(a2)
folium.Marker([23.13640232776799, 72.54229040698733],zoom_start=15,tooltip="vaishnodevi cir",popup="Amazing Ahmedabad",
             icon=folium.features.Icon(icon="airoplane")).add_to(a3)
a1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
state="US_Unemployment_Oct2012.csv"
